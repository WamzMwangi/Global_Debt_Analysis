# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ###  Analysis of Household Debt across countries of different income levels

# %% [markdown]
# #### Data Cleaning

# %%
#read data
file_path=r'C:\Users\User\Desktop\Global Debt Database\household_debt.csv'
house_debt=pd.read_csv(file_path,encoding='latin1')

# %%
house_debt.head()
# Out:
#   country_name                                     indicator_name  1950  1951  \
# 0  Afghanistan  Annual average of household debt, loans and de...   NaN   NaN
# 1      Albania  Annual average of household debt, loans and de...   NaN   NaN
# 2    Argentina  Annual average of household debt, loans and de...   NaN   NaN
# 3    Australia  Annual average of household debt, loans and de...   NaN   NaN
# 4      Austria  Annual average of household debt, loans and de...   NaN   NaN
#
#    1952  1953  1954  1955  1956  1957  ...        2013        2014  \
# 0   NaN   NaN   NaN   NaN   NaN   NaN  ...    0.872437    0.697100
# 1   NaN   NaN   NaN   NaN   NaN   NaN  ...   10.944784   10.729247
# 2   NaN   NaN   NaN   NaN   NaN   NaN  ...    6.190832    5.720705
# 3   NaN   NaN   NaN   NaN   NaN   NaN  ...  111.617878  115.536449
# 4   NaN   NaN   NaN   NaN   NaN   NaN  ...   50.968756   50.242221
#
#          2015        2016        2017        2018        2019        2020  \
# ...

# %%
#Filter out to include only sample countries
countries=['Afghanistan','Burundi','Burkina Faso','Sri Lanka','Bolivia','Kenya','Mexico','Russian Federation',
           'Indonesia','Saudi Arabia','Germany','United States']

# %%
house_debt=house_debt[house_debt['country_name'].isin(countries)]

# %%
#now we drop columns of years outside our range of interest-2010-2022
house_debt=house_debt.drop(house_debt.iloc[:,2:62].columns, axis=1, inplace=False)

# %%
house_debt
# Out:
#           country_name                                     indicator_name  \
# 0          Afghanistan  Annual average of household debt, loans and de...
# 26             Germany  Annual average of household debt, loans and de...
# 33           Indonesia  Annual average of household debt, loans and de...
# 48              Mexico  Annual average of household debt, loans and de...
# 62  Russian Federation  Annual average of household debt, loans and de...
# 64        Saudi Arabia  Annual average of household debt, loans and de...
# 72           Sri Lanka  Annual average of household debt, loans and de...
# 82       United States  Annual average of household debt, loans and de...
#
#          2010       2011       2012       2013       2014       2015  \
# 0    1.431380   1.222644   1.103867   0.872437   0.697100   0.577473
# 26  59.392723  57.122210  56.577399  55.651342  54.211920  53.630485
# 33  13.610181  15.219752  16.433954  17.012848  17.063245  16.796649
# ...

# %% [markdown]
# ### Dealing with missing values

# %%
house_debt.isnull()
# Out:
#     country_name  indicator_name   2010   2011   2012   2013   2014   2015  \
# 0          False           False  False  False  False  False  False  False
# 26         False           False  False  False  False  False  False  False
# 33         False           False  False  False  False  False  False  False
# 48         False           False  False  False  False  False  False  False
# 62         False           False  False  False  False  False  False  False
# 64         False           False  False  False  False  False  False  False
# 72         False           False  False  False  False  False  False  False
# 82         False           False  False  False  False  False  False  False
#
#      2016   2017   2018   2019   2020   2021   2022
# 0   False  False  False  False  False   True   True
# 26  False  False  False  False  False  False  False
# 33  False  False  False  False  False  False  False
# 48  False  False  False  False  False  False  False
# ...
