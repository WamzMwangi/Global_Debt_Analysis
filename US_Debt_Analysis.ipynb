# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Preparing Data for Analysis
# Getting data from different sources and joining it to one main dataframe

# %% [markdown]
# #### Preparing Central Government Debt Data

# %%
#read data
fp_gov=r"C:\Users\User\Desktop\Global Debt Database\central_government_debt.csv"
gov=pd.read_csv(fp_gov,encoding='latin1')

# %%
gov.head()
# Out:
#           country_name                                     indicator_name  \
# 0          Afghanistan  Annual average of central government debt (Per...
# 1              Albania  Annual average of central government debt (Per...
# 2              Algeria  Annual average of central government debt (Per...
# 3               Angola  Annual average of central government debt (Per...
# 4  Antigua and Barbuda  Annual average of central government debt (Per...
#
#    1950  1951  1952  1953  1954  1955  1956  1957  ...       2013        2014  \
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   6.904479    8.700291
# 1   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...  65.530002   70.030002
# 2   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   7.093511    7.658320
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...  33.149104   39.809857
# 4   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...  95.791048  101.369132
#
# ...

# %%
gov=gov.loc[gov['country_name']=='United States']

# %%
gov.head()
# Out:
#       country_name                                     indicator_name  \
# 164  United States  Annual average of central government debt (Per...
#
#           1950       1951       1952       1953       1954       1955  \
# 164  78.199645  68.201929  66.341449  64.602206  64.955715  59.520558
#
#           1956       1957  ...      2013       2014       2015       2016  \
# 164  55.370304  52.249566  ...  85.13749  85.921972  86.910377  89.356682
#
#           2017       2018       2019        2020        2021        2022
# 164  88.990263  90.962795  93.073615  118.420751  113.705197  110.146803
#
# [1 rows x 75 columns]

# %%
gov.transpose()
# Out:
#                                                               164
# country_name                                        United States
# indicator_name  Annual average of central government debt (Per...
# 1950                                                    78.199645
# 1951                                                    68.201929
# 1952                                                    66.341449
# ...                                                           ...
# 2018                                                    90.962795
# 2019                                                    93.073615
# 2020                                                   118.420751
# 2021                                                   113.705197
# 2022                                                   110.146803
#
# [75 rows x 1 columns]

# %%
gov_debt=gov.drop(['country_name','indicator_name'],axis=1).transpose(copy=False)

# %%
gov_debt.head()
# Out:
#             164
# 1950  78.199645
# 1951  68.201929
# 1952  66.341449
# 1953  64.602206
# 1954  64.955715

# %%
gov_debt.columns
# Out:
# Index([164], dtype='int64')

# %%
gov_debt.rename(columns = {164:'Central Government Debt'}, inplace = True)

# %%
gov_debt.tail()
# Out:
#       Central Government Debt
# 2018                90.962795
# 2019                93.073615
# 2020               118.420751
# 2021               113.705197
# 2022               110.146803

# %% [markdown]
#  ### Prepariing Household Debt Data

# %%
fp_house=r"C:\Users\User\Desktop\Global Debt Database\household_debt.csv"
house=pd.read_csv(fp_house, encoding='latin1')

# %%
house.head()
# Out:
#   country_name                                     indicator_name  1950  1951  \
# 0  Afghanistan  Annual average of household debt, loans and de...   NaN   NaN
# 1      Albania  Annual average of household debt, loans and de...   NaN   NaN
# 2    Argentina  Annual average of household debt, loans and de...   NaN   NaN
# 3    Australia  Annual average of household debt, loans and de...   NaN   NaN
# 4      Austria  Annual average of household debt, loans and de...   NaN   NaN
#
#    1952  1953  1954  1955  1956  1957  ...        2013        2014  \
# 0   NaN   NaN   NaN   NaN   NaN   NaN  ...    0.872437    0.697100
# 1   NaN   NaN   NaN   NaN   NaN   NaN  ...   10.944784   10.729247
# 2   NaN   NaN   NaN   NaN   NaN   NaN  ...    6.190832    5.720705
# 3   NaN   NaN   NaN   NaN   NaN   NaN  ...  111.617878  115.536449
# 4   NaN   NaN   NaN   NaN   NaN   NaN  ...   50.968756   50.242221
#
#          2015        2016        2017        2018        2019        2020  \
# ...

# %%
#filter to get Kenya data only
house=house.loc[house['country_name']=='United States']

# %%
house.head()
# Out:
#      country_name                                     indicator_name  \
# 82  United States  Annual average of household debt, loans and de...
#
#          1950      1951       1952       1953       1954       1955  \
# 82  24.802614  23.91165  25.976296  27.794074  30.862721  33.318558
#
#          1956       1957  ...       2013      2014       2015       2016  \
# 82  34.880478  35.738266  ...  82.521192  79.86992  77.942384  78.098646
#
#          2017       2018       2019       2020       2021       2022
# 82  77.759808  75.986963  75.276262  79.348115  76.944509  74.438409
#
# [1 rows x 75 columns]

# %%
house=house.transpose(copy=False)

# %%
house
# Out:
#                                                                82
# country_name                                        United States
# indicator_name  Annual average of household debt, loans and de...
# 1950                                                    24.802614
# 1951                                                     23.91165
# 1952                                                    25.976296
# ...                                                           ...
# 2018                                                    75.986963
# 2019                                                    75.276262
# 2020                                                    79.348115
# 2021                                                    76.944509
# 2022                                                    74.438409
#
# [75 rows x 1 columns]

# %%
#drop the first 2 rows
house_debt=house.drop(['country_name','indicator_name'],axis=0)

# %%
house_debt.head()
# Out:
#              82
# 1950  24.802614
# 1951   23.91165
# 1952  25.976296
# 1953  27.794074
# 1954  30.862721

# %%
house_debt.rename(columns={82:'Household Debt'},inplace=True)

# %%
#gov_debt.rename(columns = {164:'Central Government Debt'}, inplace = True)

# %%
house_debt.head()
# Out:
#      Household Debt
# 1950      24.802614
# 1951       23.91165
# 1952      25.976296
# 1953      27.794074
# 1954      30.862721

# %% [markdown]
# ### Preparing Private Debt Data

# %%
fp_private=r"C:\Users\User\Desktop\Global Debt Database\private_debt.csv"
private=pd.read_csv(fp_private, encoding='latin1')

# %%
private.head()
# Out:
#   country_name                                      indicator_name       1950  \
# 0   Afghanistan  Annual average of private debt, loans and debt...        NaN
# 1       Albania  Annual average of private debt, loans and debt...        NaN
# 2       Algeria  Annual average of private debt, loans and debt...        NaN
# 3     Argentina  Annual average of private debt, loans and debt...  66.646476
# 4     Australia  Annual average of private debt, loans and debt...        NaN
#
#         1951       1952       1953       1954       1955       1956  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN
# 3  63.241907  67.335064  67.413434  72.982788  73.801149  69.848257
# 4        NaN        NaN  52.220219  56.321358  60.894213  56.857488
#
#         1957  ...        2013        2014        2015        2016        2017  \
# ...

# %%
priv_debt=private.loc[private['country_name ']== 'United States']

# %%
priv_debt.head()
# Out:
#      country_name                                      indicator_name  \
# 151  United States  Annual average of private debt, loans and debt...
#
#           1950       1951       1952       1953       1954       1955  \
# 151  55.314634  53.657228  56.555505  58.016532  62.573558  65.340243
#
#           1956       1957  ...        2013        2014        2015  \
# 151  68.086068  69.871723  ...  149.987369  149.000879  149.049175
#
#            2016        2017        2018        2019        2020        2021  \
# 151  150.841343  152.527166  151.701438  151.540834  163.892462  157.036552
#
#            2022
# 151  152.495388
#
# [1 rows x 75 columns]

# %%
priv_debt=priv_debt.transpose(copy=False)

# %%
#drop unnecessary rows
priv_debt=priv_debt.drop(['country_name ', 'indicator_name'], axis=0)

# %%
priv_debt.tail()
# Out:
#              151
# 2018  151.701438
# 2019  151.540834
# 2020  163.892462
# 2021  157.036552
# 2022  152.495388

# %%
priv_debt.rename(columns={151:'Private Debt'}, inplace= True)

# %%
priv_debt.head()
# Out:
#      Private Debt
# 1950    55.314634
# 1951    53.657228
# 1952    56.555505
# 1953    58.016532
# 1954    62.573558

# %% [markdown]
# ### Preparing Non-Financial Corporate Debt

# %%
#read data
fp_corp=r"C:\Users\User\Desktop\Global Debt Database\non-financial_corporate_debt.csv"
corp=pd.read_csv(fp_corp, encoding='latin1')

# %%
#filter our United States
corp=corp.loc[corp['country_name ']=='United States']

# %%
corp.head()
# Out:
#     country_name                                      indicator_name  \
# 82  United States  Annual average of nonfinancial corporate debt,...
#
#         1950       1951       1952       1953       1954       1955      1956  \
# 82  30.51202  29.745577  30.579209  30.222458  31.710837  32.021685  33.20559
#
#          1957  ...       2013       2014      2015       2016       2017  \
# 82  34.133457  ...  67.466177  69.130959  71.10679  72.742697  74.767358
#
#          2018       2019       2020       2021       2022
# 82  75.714475  76.264572  84.544347  80.092043  78.056979
#
# [1 rows x 75 columns]

# %%
corp_debt=corp.transpose(copy=False)

# %%
corp_debt.head()
# Out:
#                                                                82
# country_name                                        United States
# indicator_name  Annual average of nonfinancial corporate debt,...
# 1950                                                     30.51202
# 1951                                                    29.745577
# 1952                                                    30.579209

# %%
#drop columns
corp_debt=corp_debt.drop(['country_name ','indicator_name'],axis=0)

# %%
corp_debt.rename(columns={82:'Non- Financial Corporate Debt'}, inplace= True)

# %%
corp_debt.tail()
# Out:
#      Non- Financial Corporate Debt
# 2018                     75.714475
# 2019                     76.264572
# 2020                     84.544347
# 2021                     80.092043
# 2022                     78.056979

# %% [markdown]
# ## Joining the 4 DataFrames

# %%
data=pd.merge(gov_debt, house_debt, right_index=True, left_index=True)

# %%
data.head()
# Out:
#       Central Government Debt Household Debt
# 1950                78.199645      24.802614
# 1951                68.201929       23.91165
# 1952                66.341449      25.976296
# 1953                64.602206      27.794074
# 1954                64.955715      30.862721

# %%
data=pd.merge(data,priv_debt, right_index=True, left_index=True)

# %%
data.head()
# Out:
#       Central Government Debt Household Debt Private Debt
# 1950                78.199645      24.802614    55.314634
# 1951                68.201929       23.91165    53.657228
# 1952                66.341449      25.976296    56.555505
# 1953                64.602206      27.794074    58.016532
# 1954                64.955715      30.862721    62.573558

# %%
data=pd.merge(data,corp_debt, right_index=True, left_index=True)

# %%
data.head()
# Out:
#       Central Government Debt Household Debt Private Debt  \
# 1950                78.199645      24.802614    55.314634
# 1951                68.201929       23.91165    53.657228
# 1952                66.341449      25.976296    56.555505
# 1953                64.602206      27.794074    58.016532
# 1954                64.955715      30.862721    62.573558
#
#      Non- Financial Corporate Debt
# 1950                      30.51202
# 1951                     29.745577
# 1952                     30.579209
# 1953                     30.222458
# 1954                     31.710837

# %%
]
